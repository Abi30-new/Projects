# %% [markdown]
# <a href="https://colab.research.google.com/github/Abi30-new/Projects/blob/main/Stock_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
sp500=yf.Ticker("^GSPC")

# %%
sp500=sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-31 00:00:00-04:00  5527.910156  5627.560059  5488.729980  5611.850098
# 2025-04-01 00:00:00-04:00  5597.529785  5650.569824  5558.520020  5633.069824
# 2025-04-02 00:00:00-04:00  5580.759766  5695.310059  5571.479980  5670.970215
# 2025-04-03 00:00:00-04:00  5492.740234  5499.529785  5390.830078  5396.520020
# 2025-04-04 00:00:00-04:00  5292.140137  5292.140137  5069.899902  5074.080078
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-03-24 00:00:00-04:00', '2025-03-25 00:00:00-04:00',
#                '2025-03-26 00:00:00-04:00', '2025-03-27 00:00:00-04:00',
#                '2025-03-28 00:00:00-04:00', '2025-03-31 00:00:00-04:00',
#                '2025-04-01 00:00:00-04:00', '2025-04-02 00:00:00-04:00',
#                '2025-04-03 00:00:00-04:00', '2025-04-04 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24431, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True) #visualization of the data
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]

# %%
del sp500["Stock Splits"]

# %%
#setting the target for ML will stock go up or down??

# %%
sp500 ["Tomorrow"]= sp500 ["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-31 00:00:00-04:00  5527.910156  5627.560059  5488.729980  5611.850098
# 2025-04-01 00:00:00-04:00  5597.529785  5650.569824  5558.520020  5633.069824
# 2025-04-02 00:00:00-04:00  5580.759766  5695.310059  5571.479980  5670.970215
# 2025-04-03 00:00:00-04:00  5492.740234  5499.529785  5390.830078  5396.520020
# 2025-04-04 00:00:00-04:00  5292.140137  5292.140137  5069.899902  5074.080078
#
# ...

# %%
sp500["Target"]=(sp500["Tomorrow"]>sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-31 00:00:00-04:00  5527.910156  5627.560059  5488.729980  5611.850098
# 2025-04-01 00:00:00-04:00  5597.529785  5650.569824  5558.520020  5633.069824
# 2025-04-02 00:00:00-04:00  5580.759766  5695.310059  5571.479980  5670.970215
# 2025-04-03 00:00:00-04:00  5492.740234  5499.529785  5390.830078  5396.520020
# 2025-04-04 00:00:00-04:00  5292.140137  5292.140137  5069.899902  5074.080078
#
# ...

# %%
# in Target column 1 when price went up and 0 when it went down

# %%
sp500 = sp500.loc["1998-01-01":].copy() #removing data before 1990

# %%
#Training the first model

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(n_estimators=100, min_samples_split=100,random_state=1)

train = sp500.iloc[:-100]
test= sp500.iloc[:-100]

predictors=["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds=model.predict(test[predictors]) #to see how accurate the data is

# %%
import pandas as pd
perds=pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"],preds)
# Out:
# 0.7109322602280349

# %%
#71% not a very accurate prediction

# %%
combined = pd.concat([test["Target"],perds],axis=1) #combining actual and predicted values

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    perds= model.predict(test[predictors])
    perds= pd.Series(perds, index=test.index, name="Predictions")
    combined=pd.concat([test["Target"], perds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions =[]

    for i in range(start, data.shape[0],step):
        train=data.iloc[0:i].copy()
        test= data.iloc[i:(i+step)].copy()
        predictions=predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions=backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts() #type of prediction
# Out:
# Predictions
# 0    2324
# 1    2033
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5223807181505165

# %%
predictions["Target"].value_counts()/predictions.shape[0]
# Out:
# Target
# 1    0.542575
# 0    0.457425
# Name: count, dtype: float64

# %%
horizons =[2,5,60,250,1000]
new_predictors=[]

for horizon in horizons:
    rolling_averages= sp500.rolling(horizon).mean()

    ratio_column =f"Close_Ratio_{horizon}"
    sp500[ratio_column]=sp500["Close"] / rolling_averages["Close"]

    trend_column=f"Trend_{horizon}"
    sp500[trend_column]=sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors+=[ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1998-01-02 00:00:00-05:00   970.429993   975.039978   965.729980   975.039978
# 1998-01-05 00:00:00-05:00   975.039978   982.630005   969.000000   977.070007
# 1998-01-06 00:00:00-05:00   977.070007   977.070007   962.679993   966.580017
# 1998-01-07 00:00:00-05:00   966.580017   966.580017   952.669983   964.000000
# 1998-01-08 00:00:00-05:00   964.000000   964.000000   955.039978   956.049988
# ...                                ...          ...          ...          ...
# 2025-03-31 00:00:00-04:00  5527.910156  5627.560059  5488.729980  5611.850098
# 2025-04-01 00:00:00-04:00  5597.529785  5650.569824  5558.520020  5633.069824
# 2025-04-02 00:00:00-04:00  5580.759766  5695.310059  5571.479980  5670.970215
# 2025-04-03 00:00:00-04:00  5492.740234  5499.529785  5390.830078  5396.520020
# 2025-04-04 00:00:00-04:00  5292.140137  5292.140137  5069.899902  5074.080078
#
# ...

# %%
model=RandomForestClassifier(n_estimators=200, min_samples_split=50,random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    perds= model.predict_proba(test[predictors])[:,1]
    perds[perds>= .6]=1
    perds[perds< .6]=0
    perds= pd.Series(perds, index=test.index, name="Predictions")
    combined=pd.concat([test["Target"], perds], axis=1)
    return combined

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    2324
# 1    2033
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5223807181505165
